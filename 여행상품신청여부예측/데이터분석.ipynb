# %% [markdown]
# # 데이터 안내

# %% [markdown]
# ## 1. train.csv : 학습 데이터
#     id : 샘플 아이디
#     Age : 나이
#     TypeofContact : 고객의 제품 인지 방법 (회사의 홍보 or 스스로 검색)
#     CityTier : 주거 중인 도시의 등급. (인구, 시설, 생활 수준 기준) (1등급 > 2등급 > 3등급)
#     DurationOfPitch : 영업 사원이 고객에게 제공하는 프레젠테이션 기간
#     Occupation : 직업
#     Gender : 성별
#     NumberOfPersonVisiting : 고객과 함께 여행을 계획 중인 총 인원
#     NumberOfFollowups : 영업 사원의 프레젠테이션 후 이루어진 후속 조치 수
#     ProductPitched : 영업 사원이 제시한 상품
#     PreferredPropertyStar : 선호 호텔 숙박업소 등급
#     MaritalStatus : 결혼여부
#     NumberOfTrips : 평균 연간 여행 횟수
#     Passport : 여권 보유 여부 (0: 없음, 1: 있음)
#     PitchSatisfactionScore : 영업 사원의 프레젠테이션 만족도
#     OwnCar : 자동차 보유 여부 (0: 없음, 1: 있음)
#     NumberOfChildrenVisiting : 함께 여행을 계획 중인 5세 미만의 어린이 수
#     Designation : (직업의) 직급
#     MonthlyIncome : 월 급여
#     ProdTaken : 여행 패키지 신청 여부 (0: 신청 안 함, 1: 신청함)
#
# ## 2. test.csv : 테스트 데이터
#
#     id : 샘플 아이디
#     Age : 나이
#     TypeofContact : 고객의 제품 인지 방법 (회사의 홍보 or 스스로 검색)
#     CityTier : 주거 중인 도시의 등급. (인구, 시설, 생활 수준 기준) (1등급 > 2등급 > 3등급)
#     DurationOfPitch : 영업 사원이 고객에게 제공하는 프레젠테이션 기간
#     Occupation : 직업
#     Gender : 성별
#     NumberOfPersonVisiting : 고객과 함께 여행을 계획 중인 총 인원
#     NumberOfFollowups : 영업 사원의 프레젠테이션 후 이루어진 후속 조치 수
#     ProductPitched : 영업 사원이 제시한 상품
#     PreferredPropertyStar : 선호 호텔 숙박업소 등급
#     MaritalStatus : 결혼여부
#     NumberOfTrips : 평균 연간 여행 횟수
#     Passport : 여권 보유 여부 (0: 없음, 1: 있음)
#     PitchSatisfactionScore : 영업 사원의 프레젠테이션 만족도
#     OwnCar : 자동차 보유 여부 (0: 없음, 1: 있음)
#     NumberOfChildrenVisiting : 함께 여행을 계획 중인 5세 미만의 어린이 수
#     Designation : (직업의) 직급
#     MonthlyIncome : 월 급여
#
# ## 3. sample_submission.csv : 제출 양식
#     id : 샘플 아이디
#     ProdTaken : 여행 패키지 신청 여부 (0: 신청 안 함, 1: 신청함)

# %% [markdown]
# # I. 데이터 살펴보기

# %% [markdown]
# ## 1. Google Colab

# %%
from google.colab import drive
drive.mount('/content/drive')

import warnings
warnings.filterwarnings('ignore')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## 2. 데이터 준비

# %%
# 데이터를 불러오고 살펴보기 위한 pandas 라이브러리
import pandas as pd

# train 데이터 불러오기
train = pd.read_csv('/content/drive/MyDrive/DACON/여행상품신청여부예측/data/train.csv', index_col = 'id')

# test 데이터 불러오기
test = pd.read_csv('/content/drive/MyDrive/DACON/여행상품신청여부예측/data/test.csv', index_col = 'id')

# sample_submission 불러오기
sample_submission = pd.read_csv('/content/drive/MyDrive/DACON/여행상품신청여부예측/data/sample_submission.csv')

# %%
# 컬럼 리스트
col_list = train.columns
col_list
# Out:
# Index(['Age', 'TypeofContact', 'CityTier', 'DurationOfPitch', 'Occupation',
#        'Gender', 'NumberOfPersonVisiting', 'NumberOfFollowups',
#        'ProductPitched', 'PreferredPropertyStar', 'MaritalStatus',
#        'NumberOfTrips', 'Passport', 'PitchSatisfactionScore', 'OwnCar',
#        'NumberOfChildrenVisiting', 'Designation', 'MonthlyIncome',
#        'ProdTaken'],
#       dtype='object')

# %%
# 잘 불러와졌는지 확인합니다
train
# Out:
#        Age    TypeofContact  CityTier  DurationOfPitch      Occupation  \
# id
# 1     28.0  Company Invited         1             10.0  Small Business
# 2     34.0     Self Enquiry         3              NaN  Small Business
# 3     45.0  Company Invited         1              NaN        Salaried
# 4     29.0  Company Invited         1              7.0  Small Business
# 5     42.0     Self Enquiry         3              6.0        Salaried
# ...    ...              ...       ...              ...             ...
# 1951  28.0     Self Enquiry         1             10.0  Small Business
# 1952  41.0     Self Enquiry         3              8.0        Salaried
# 1953  38.0  Company Invited         3             28.0  Small Business
# 1954  28.0     Self Enquiry         3             30.0  Small Business
# 1955  22.0  Company Invited         1              9.0        Salaried
#
#       Gender  NumberOfPersonVisiting  NumberOfFollowups ProductPitched  \
# id
# ...

# %% [markdown]
# ## 3. 데이터 확인

# %%
# 데이터를 살펴보기 위해 데이터 최상단의 5줄을 표시합니다
train.head()
# Out:
#      Age    TypeofContact  CityTier  DurationOfPitch      Occupation  Gender  \
# id
# 1   28.0  Company Invited         1             10.0  Small Business    Male
# 2   34.0     Self Enquiry         3              NaN  Small Business  Female
# 3   45.0  Company Invited         1              NaN        Salaried    Male
# 4   29.0  Company Invited         1              7.0  Small Business    Male
# 5   42.0     Self Enquiry         3              6.0        Salaried    Male
#
#     NumberOfPersonVisiting  NumberOfFollowups ProductPitched  \
# id
# 1                        3                4.0          Basic
# 2                        2                4.0         Deluxe
# 3                        2                3.0         Deluxe
# 4                        3                5.0          Basic
# 5                        2                3.0         Deluxe
#
#     PreferredPropertyStar MaritalStatus  NumberOfTrips  Passport  \
# id
# ...

# %%
# 데이터를 살펴보기 위해 데이터 최하단의 5줄을 표시합니다
train.tail()
# Out:
#        Age    TypeofContact  CityTier  DurationOfPitch      Occupation  \
# id
# 1951  28.0     Self Enquiry         1             10.0  Small Business
# 1952  41.0     Self Enquiry         3              8.0        Salaried
# 1953  38.0  Company Invited         3             28.0  Small Business
# 1954  28.0     Self Enquiry         3             30.0  Small Business
# 1955  22.0  Company Invited         1              9.0        Salaried
#
#       Gender  NumberOfPersonVisiting  NumberOfFollowups ProductPitched  \
# id
# 1951    Male                       3                5.0          Basic
# 1952  Female                       3                3.0   Super Deluxe
# 1953  Female                       3                4.0          Basic
# 1954  Female                       3                5.0         Deluxe
# 1955    Male                       2                4.0          Basic
#
#       PreferredPropertyStar MaritalStatus  NumberOfTrips  Passport  \
# id
# ...

# %%
# 데이터 결측치 및 변수들의 타입 확인
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1955 entries, 1 to 1955
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1861 non-null   float64
#  1   TypeofContact             1945 non-null   object
#  2   CityTier                  1955 non-null   int64
#  3   DurationOfPitch           1853 non-null   float64
#  4   Occupation                1955 non-null   object
#  5   Gender                    1955 non-null   object
#  6   NumberOfPersonVisiting    1955 non-null   int64
#  7   NumberOfFollowups         1942 non-null   float64
#  8   ProductPitched            1955 non-null   object
#  9   PreferredPropertyStar     1945 non-null   float64
#  10  MaritalStatus             1955 non-null   object
#  11  NumberOfTrips             1898 non-null   float64
#  12  Passport                  1955 non-null   int64
# ...

# %%
print(train.isnull().sum())
# Out:
# Age                          94
# TypeofContact                10
# CityTier                      0
# DurationOfPitch             102
# Occupation                    0
# Gender                        0
# NumberOfPersonVisiting        0
# NumberOfFollowups            13
# ProductPitched                0
# PreferredPropertyStar        10
# MaritalStatus                 0
# NumberOfTrips                57
# Passport                      0
# PitchSatisfactionScore        0
# OwnCar                        0
# NumberOfChildrenVisiting     27
# Designation                   0
# MonthlyIncome               100
# ProdTaken                     0
# dtype: int64

# %%
# 컬럼별 고유값 확인
for col in train.columns:
  cols = str(col)
  print(f'{col} 고유값 : {train[cols].unique()} \n')
# Out:
# Age 고유값 : [28. 34. 45. 29. 42. 32. 43. 36. 35. 31. 49. nan 52. 33. 22. 50. 23. 41.
#  37. 40. 56. 54. 39. 20. 46. 27. 38. 25. 26. 24. 30. 21. 51. 47. 55. 44.
#  53. 48. 18. 57. 60. 59. 19. 58. 61.]
#
# TypeofContact 고유값 : ['Company Invited' 'Self Enquiry' nan]
#
# CityTier 고유값 : [1 3 2]
#
# DurationOfPitch 고유값 : [10. nan  7.  6. 29.  8. 20. 14.  9. 16. 15. 23. 21. 11. 25. 34. 17. 13.
#  28. 12. 22. 30. 24. 27. 31. 35. 32. 33. 36. 19. 26. 18.  5.]
#
# Occupation 고유값 : ['Small Business' 'Salaried' 'Large Business' 'Free Lancer']
#
# Gender 고유값 : ['Male' 'Female' 'Fe Male']
#
# NumberOfPersonVisiting 고유값 : [3 2 4 1 5]
#
# NumberOfFollowups 고유값 : [ 4.  3.  5.  1.  6.  2. nan]
#
# ProductPitched 고유값 : ['Basic' 'Deluxe' 'King' 'Standard' 'Super Deluxe']
#
# PreferredPropertyStar 고유값 : [ 3.  4.  5. nan]
#
# MaritalStatus 고유값 : ['Married' 'Single' 'Divorced' 'Unmarried']
#
# NumberOfTrips 고유값 : [ 3.  1.  2.  7.  4.  6.  5.  8. nan 19.]
#
# Passport 고유값 : [0 1]
#
# ...

# %% [markdown]
# - Gender 컬럼의 Fe Male -> Female로 변환 필요

# %%
# Fe male -> Female
train.replace({'Gender':'Fe Male'}, 'Female', inplace=True)
test.replace({'Gender':'Fe Male'}, 'Female', inplace=True)

# %% [markdown]
# **이진형 데이터**<br>
#
# - TypeofContact
# - Gender
# - MaritalStatus
# - Passport
# - OwnCar
# - ProdTaken
#
# **순서형 데이터**<br>
#
# - CityTier
# - PreferredPropertyStar
# - PitchSatisfactionScore
# - Designation
#
# **이산형 데이터**<br>
#
# - Age
# - MonthlyIncome
#
# **명목형 데이터**<br>
#
# - Occupation
# - ProductPitched
# - DurationOfPitch
# - NumberOfPersonVisiting
# - NumberOfFollowups
# - NumberOfChildrenVisiting

# %% [markdown]
# ## 4. 결측값 처리

# %%
import missingno as msno
import matplotlib.pyplot as plt
import seaborn as sns 
from copy import deepcopy

# %%
print('결측값을 가진 행의 갯수:', sum(train.isnull().sum(1) > 0))
# Out:
# 결측값을 가진 행의 갯수: 306

# %%
# 결측값 그래프로 확인
msno.matrix(train)

# %% [markdown]
# - 결측치가 있는 행이 306개로 큰 비율을 차지하지 않지만, train데이터 갯수가 약 1900개 이므로 삭제하지 않고 중앙값 및 최빈값으로 채워준다.
# - Age : 중앙값으로 채운다.
# - DurationOfPitch : 프레젠테이션을 하지 않은 경우를 생각하여 0으로 채워준다.
# - TypeofContact, NumberOfFollowups,PreferredPropertyStar, NumberOfTrips : 최빈값으로 채운다.
# - NumberOfChildrenVisiting : 5세 미만의 어린이가 없는 경우를 생각하여 0으로 채워준다.
# - MonthlyIncome : 직급과 연관이 있을 것이라 예상. 직급별 급여의 평균값으로 결측치를 채워준다.

# %%
# 결측값을 가진 행들을 모은 표
train_null = train[train.isnull().sum(1) > 0]
train_null.head()
# Out:
#      Age    TypeofContact  CityTier  DurationOfPitch      Occupation  Gender  \
# id
# 2   34.0     Self Enquiry         3              NaN  Small Business  Female
# 3   45.0  Company Invited         1              NaN        Salaried    Male
# 9   36.0  Company Invited         3              NaN  Small Business  Female
# 14   NaN     Self Enquiry         3              6.0  Small Business    Male
# 15  52.0  Company Invited         3             16.0        Salaried    Male
#
#     NumberOfPersonVisiting  NumberOfFollowups ProductPitched  \
# id
# 2                        2                4.0         Deluxe
# 3                        2                3.0         Deluxe
# 9                        2                1.0         Deluxe
# 14                       2                1.0         Deluxe
# 15                       3                4.0           King
#
#     PreferredPropertyStar MaritalStatus  NumberOfTrips  Passport  \
# id
# ...

# %%
fig, ax = plt.subplots(nrows = 4, ncols = 5) # 20 subplots
fig.set_size_inches(20,24) # set figure size

for i in range(4):
    for j in range(5):
        if 5 * i + j >= len(col_list) : break 
        var_name = col_list[5 * i + j] 
        if(train_null[var_name].dtype == 'float64'): # 변수가 이산형일 경우
            sns.histplot(train_null[var_name], ax = ax[i][j]) # histogram
        else : # 그 외
            sns.countplot(x = train_null[var_name] , ax = ax[i][j]) # count plot
        ax[i][j].set(title = var_name , ylabel = '') # plot 제목

# %%
# Age
train['Age'] = train.loc[:, 'Age'].fillna(train['Age'].median())
test['Age'] = test.loc[:, 'Age'].fillna(test['Age'].median())

# %%
# TypeofContact
train['TypeofContact'] = train.loc[:, 'TypeofContact'].fillna('Self Enquiry')
test['TypeofContact'] = test.loc[:, 'TypeofContact'].fillna('Self Enquiry')

# %%
# DurationOfPitch
train['DurationOfPitch'] = train.loc[:, 'DurationOfPitch'].fillna(0)
test['DurationOfPitch'] = test.loc[:, 'DurationOfPitch'].fillna(0)

# %%
# NumberOfFollowups
train['NumberOfFollowups'] = train.loc[:, 'NumberOfFollowups'].fillna(0)
test['NumberOfFollowups'] = test.loc[:, 'NumberOfFollowups'].fillna(0)

# %%
# PreferredPropertyStar
train['PreferredPropertyStar'] = train.loc[:, 'PreferredPropertyStar'].fillna(3.0)
test['PreferredPropertyStar'] = test.loc[:, 'PreferredPropertyStar'].fillna(3.0)

# %%
# NumberOfTrips
train['NumberOfTrips'] = train.loc[:, 'NumberOfTrips'].fillna(2.0)
test['NumberOfTrips'] = test.loc[:, 'NumberOfTrips'].fillna(2.0)

# %%
# NumberOfChildrenVisiting
train['NumberOfChildrenVisiting'] = train.loc[:, 'NumberOfChildrenVisiting'].fillna(0)
test['NumberOfChildrenVisiting'] = test.loc[:, 'NumberOfChildrenVisiting'].fillna(0)

# %%
# MonthlyIncome
train['MonthlyIncome'].fillna(train.groupby('Designation')['MonthlyIncome'].transform('mean'), inplace=True)
test['MonthlyIncome'].fillna(test.groupby('Designation')['MonthlyIncome'].transform('mean'), inplace=True)

# %%
# train, test 데이터 결측치 처리 결과 확인
print('<train>\n',train.isnull().sum())
print()
print('<test>\n', test.isnull().sum())
# Out:
# <train>
#  Age                         0
# TypeofContact               0
# CityTier                    0
# DurationOfPitch             0
# Occupation                  0
# Gender                      0
# NumberOfPersonVisiting      0
# NumberOfFollowups           0
# ProductPitched              0
# PreferredPropertyStar       0
# MaritalStatus               0
# NumberOfTrips               0
# Passport                    0
# PitchSatisfactionScore      0
# OwnCar                      0
# NumberOfChildrenVisiting    0
# Designation                 0
# MonthlyIncome               0
# ProdTaken                   0
# dtype: int64
#
# <test>
#  Age                         0
# TypeofContact               0
# CityTier                    0
# DurationOfPitch             0
# Occupation                  0
# Gender                      0
# NumberOfPersonVisiting      0
# NumberOfFollowups           0
# ProductPitched              0
# PreferredPropertyStar       0
# MaritalStatus               0
# ...

# %% [markdown]
# # II. 시각화(및 EDA)

# %%
# 컬럼별 ProdTaken 분포
# 이산형 변수라면 Box plot으로, 그외는 Count plot으로

fig, ax = plt.subplots(nrows = 4, ncols = 5) # 20 subplots
fig.set_size_inches(20,24) # set figure size

for i in range(4):
    for j in range(5):
        if 5 * i + j >= 19 : break
        var_name = col_list[5 * i + j]
        if var_name == 'ProdTaken' : 
            sns.countplot(x = train[var_name], ax = ax[i][j])
        elif(train[var_name].dtype == 'float64'): 
            if train[var_name].max() < 6 : 
                sns.countplot(data = train, x = var_name, hue = 'ProdTaken' , ax = ax[i][j]) # count plot
            else :
                sns.boxplot(data = train, x = 'ProdTaken', y = var_name , ax = ax[i][j]) # Box plot
        else : 
            sns.countplot(data = train, x = var_name, hue = 'ProdTaken' , ax = ax[i][j]) # count plot
        ax[i][j].set(title = var_name , ylabel = '') # set title of each plot

# %% [markdown]
# ## 1. 연령대별 어떤 상품을 추천하면 좋을까?
# - 여행 스타일과 관련된 컬럼은 **PreferredPropertyStar(선호 호텔 숙박업소 등급), NumberOfTrips(평균 연간 여행 횟수), Passport(여권 보유 여부), OwnCar(자동차 보유 여부), ProdTaken(여행 패키지 신청 여부)** 으로 생각하겠습니다.
# - 이 중 연령대별 *선호 호텔 숙박업소 등급*, *자동차 보유여부*, *여행 패키지 신청 여부*를 통해 연령대별로 어떤 상품을 기획하면 좋을지 알아보겠습니다.

# %%
# Age 카테고리 분류
# 10대와 60대 이상의 비율이 적으므로 10대는 20대에 포함, 60대이상은 50대에 포함

def age_category(age):
    if age < 20:
        age = 20
    elif age >= 60:
        age = 50
    else: 
        age = (age // 10) * 10
    return age

# %%
# train에 적용
train['age_category'] = train['Age'].apply(age_category)
train['age_category'].astype('int64')
# Out:
# id
# 1       20
# 2       30
# 3       40
# 4       20
# 5       40
#         ..
# 1951    20
# 1952    40
# 1953    30
# 1954    20
# 1955    20
# Name: age_category, Length: 1955, dtype: int64

# %%
# 여행 스타일 컬럼 재정의
# col_list_style = ['PreferredPropertyStar', 'OwnCar', 'ProdTaken']

# %% [markdown]
# ### 1-1. Age Category 분포 확인

# %%
fig.set_size_inches(8, 12)
sns.countplot(data = train, x = 'age_category')

# %% [markdown]
# - 30대가 가장 많고 50대 이상이 가장 적습니다.
# - 현재 여행상품은 30대와 40대에게 인기가 많다는 것을 알 수 있습니다.

# %% [markdown]
# ### 1-2. PreferredPropertyStar(선호 호텔 숙박업소 등급)

# %%
sns.countplot(data = train, x = 'PreferredPropertyStar', hue = 'age_category')

# %% [markdown]
# - 선호 호텔 숙박업소 등급은 3등급이 가장 많음으로 나타났습니다.
# - 4등급과 5등급의 선호도 차이는 50대 이상을 제외한 나이대에서 크게 차이나지 않음을 알 수 있습니다.
# - 따라서 여행 패키지를 신청한 사람들 중 선호하는 호텔 등급을 알아보는 것이 좋을 것 같습니다.

# %%
# 여행 패키지를 신청한 사람들의 선호 호텔 등급
prod_taken = train.loc[train['ProdTaken'] == 1] # 여행 패키지 신청한 사람들 데이터프레임
sns.countplot(data = prod_taken, x = 'PreferredPropertyStar', hue = 'age_category')

# %% [markdown]
# - 여행 패키지를 신청한 사람들 중 20대(10대 포함)와 30대는 3등급, 5등급, 4등급 순으로 선호하는 것을 알 수 있습니다.
# - 따라서 20대(10대 포함)와 30대를 대상으로 한다면 3등급 호텔과 5등급 호텔이 포함된 여행 패키지를, 40대 이상이 대상이라면 3등급 호텔과 4등급 호텔이 포함된 여행 패키지를 기획하는 것이 좋을 것입니다.

# %% [markdown]
# ### 1-3. OwnCar(자동차 보유 여부)
# - 자동차를 보유하고 있다면 국내 여행 패키지를 판매할 수 있을 것입니다.
# - 전체 데이터에서 자동차를 보유한 사람이 자동차를 보유하지 않은 사람보다 많음을 알 수 있었습니다.
# - 먼저 어느 나이대가 가장 많이 자동차를 보유하였는지 알아보겠습니다.

# %%
# 자동차를 보유한 사람들 나이대 확인
own_car = train.loc[train['OwnCar'] == 1] # 자동차를 보유한 열 데이터프레임
sns.countplot(data = own_car, x = 'OwnCar', hue = 'age_category')

# %% [markdown]
# - 자동차를 보유한 사람들의 나이대는 역시 30대와 40대의 수가 많음으로 나타났습니다.
# - 이는 전체 데이터에 30대와 40대의 수가 많기 때문에 당연한 결과입니다.
# - 조금 더 유의미한 분석을 위해 나이대별로 자동차를 보유한 사람과 보유하지 않은 사람의 비율을 알아보겠습니다.

# %%
# 나이대별 데이터프레임 만들기
train_twenty = train.loc[train['age_category'] == 20.0] # 20대
train_thirty = train.loc[train['age_category'] == 30.0] # 30대
train_fourty = train.loc[train['age_category'] == 40.0] # 40대
train_fifty = train.loc[train['age_category'] == 50.0] # 50대

# %%
# 파이그래프로 비율 알아보기
f, ax = plt.subplots(1, 4, figsize=(15,5))

train_twenty['OwnCar'].value_counts().plot.pie(explode=[0,0.1],
                                           autopct='%1.1f%%', 
                                           ax=ax[0], 
                                           shadow=True)
train_thirty['OwnCar'].value_counts().plot.pie(explode=[0,0.1],
                                           autopct='%1.1f%%', 
                                           ax=ax[1], 
                                           shadow=True)
train_fourty['OwnCar'].value_counts().plot.pie(explode=[0,0.1],
                                           autopct='%1.1f%%', 
                                           ax=ax[2], 
                                           shadow=True)
train_fifty['OwnCar'].value_counts().plot.pie(explode=[0,0.1],
                                           autopct='%1.1f%%', 
                                           ax=ax[3], 
                                           shadow=True)

ax[0].set(title = "20's" , ylabel = '')
ax[1].set(title = "30's" , ylabel = '')
ax[2].set(title = "40's" , ylabel = '')
ax[3].set(title = "50's" , ylabel = '')
# Out:
# [Text(0, 0.5, ''), Text(0.5, 1.0, "50's")]

# %% [markdown]
# - 20대(10대 포함)의 경우 다른 나이대에 비하여 자동차를 보유한 사람의 비율이 낮습니다.
# - 따라서 20대를 대상으로 한다면 개인 자동차를 이용해야하는 여행 상품을 기획하는 것을 피해야 할 것입니다.
# - 30대 이상을 대상으로 한다면 개인 자동차를 이용할 수 있는 국내 여행 상품을 기획해 볼 만합니다.
# - 그 다음으로는 자동차를 보유한 여부에 따라 현 여행 패키지를 신청한 사람이 얼마나 되는지 나이대별로 알아보겠습니다.

# %%
# 자동차 보유 데이터프레임에서 나이대 데이터프레임 만들기
own_car_20 = own_car.loc[own_car['age_category'] == 20.0]
own_car_30 = own_car.loc[own_car['age_category'] == 30.0]
own_car_40 = own_car.loc[own_car['age_category'] == 40.0]
own_car_50 = own_car.loc[own_car['age_category'] == 50.0]

# %%
# 파이그래프로 나이대별 자동차를 보유한 사람들의 신청 비율 알아보기
f, ax = plt.subplots(1, 4, figsize=(15,5))

own_car_20['ProdTaken'].value_counts().plot.pie(explode=[0,0.1],
                                           autopct='%1.1f%%', 
                                           ax=ax[0], 
                                           shadow=True)
own_car_30['ProdTaken'].value_counts().plot.pie(explode=[0,0.1],
                                           autopct='%1.1f%%', 
                                           ax=ax[1], 
                                           shadow=True)
own_car_40['ProdTaken'].value_counts().plot.pie(explode=[0,0.1],
                                           autopct='%1.1f%%', 
                                           ax=ax[2], 
                                           shadow=True)
own_car_50['ProdTaken'].value_counts().plot.pie(explode=[0,0.1],
                                           autopct='%1.1f%%', 
                                           ax=ax[3], 
                                           shadow=True)

ax[0].set(title = "20's_OwnCar_ProdTaken" , ylabel = '')
ax[1].set(title = "30's_OwnCar_ProdTaken" , ylabel = '')
ax[2].set(title = "40's_OwnCar_ProdTaken" , ylabel = '')
ax[3].set(title = "50's_OwnCar_ProdTaken" , ylabel = '')
# Out:
# [Text(0, 0.5, ''), Text(0.5, 1.0, "50's_OwnCar_ProdTaken")]

# %%
# 자동차를 소유하지 않은 사람들 나이대별 데이터프레임
not_owncar_20 = train_twenty.loc[train_twenty['OwnCar'] == 0]
not_owncar_30 = train_thirty.loc[train_thirty['OwnCar'] == 0]
not_owncar_40 = train_fourty.loc[train_fourty['OwnCar'] == 0]
not_owncar_50 = train_fifty.loc[train_fifty['OwnCar'] == 0]

# %%
# 파이그래프로 나이대별 자동차를 보유하지 않은 사람들의 신청 비율 알아보기
f, ax = plt.subplots(1, 4, figsize=(15,5))
not_owncar_20['ProdTaken'].value_counts().plot.pie(explode=[0,0.1],
                                           autopct='%1.1f%%', 
                                           ax=ax[0], 
                                           shadow=True)
not_owncar_30['ProdTaken'].value_counts().plot.pie(explode=[0,0.1],
                                           autopct='%1.1f%%', 
                                           ax=ax[1], 
                                           shadow=True)
not_owncar_40['ProdTaken'].value_counts().plot.pie(explode=[0,0.1],
                                           autopct='%1.1f%%', 
                                           ax=ax[2], 
                                           shadow=True)
not_owncar_50['ProdTaken'].value_counts().plot.pie(explode=[0,0.1],
                                           autopct='%1.1f%%', 
                                           ax=ax[3], 
                                           shadow=True)

ax[0].set(title = "20's_Not_OwnCar_ProdTaken" , ylabel = '')
ax[1].set(title = "30's_Not_OwnCar_ProdTaken" , ylabel = '')
ax[2].set(title = "40's_Not_OwnCar_ProdTaken" , ylabel = '')
ax[3].set(title = "50's_Not_OwnCar_ProdTaken" , ylabel = '')
# Out:
# [Text(0, 0.5, ''), Text(0.5, 1.0, "50's_Not_OwnCar_ProdTaken")]

# %% [markdown]
# - 20대(10대 포함)의 경우 자동차를 보유하지 않은 비율이 다른 나이대에 비해 가장 높았음에도 불구하고, 자동차를 보유하지 않은 사람들 중 현 여행 패키지를 신청한 비율이 다른 나이대에비해 높았습니다.
# - 따라서 현 여행상품은 개인 자동차를 이용하지 않고 진행되는 여행일 것이라 추측해봅니다.

# %% [markdown]
# ## 2. 영업사원을 통한 영업을 개선하는 방법은?
# - 영업사원과 관련된 컬럼은 DurationOfPitch(영업 사원이 고객에게 제공하는 프레젠테이션 기간), NumberOfFollowups(영업 사원의 프레젠테이션 후 이루어진 후속 조치 수), ProductPitched(영업 사원이 제시한 상품), PitchSatisfactionScore(영업 사원의 프레젠테이션 만족도)입니다.
# - DurationOfPitch(영업 사원이 고객에게 제공하는 프레젠테이션 기간)과 NumberOfFollowups(영업 사원의 프레젠테이션 후 이루어진 후속 조치 수), ProductPitched(영업 사원이 제시한 상품)와 여행 패키지 신청 여부를 알아보겠습니다.

# %% [markdown]
# ### 2-1. DurationOfPitch(영업 사원이 고객에게 제공하는 프레젠테이션 기간)

# %%
import matplotlib.gridspec as gridspec

# %%
def write_percent(ax, total_size):
  # 도형 객체를 순회하며 막대 그래프 상단에 타깃값 비율 표시
  for patch in ax.patches:
    height = patch.get_height() # 도형 높이(데이터 개수)
    width = patch.get_width() # 도형 너비
    left_coord = patch.get_x()  # 도형 왼쪽 테두리의 x축 위치
    percent = height/total_size*100 # 타깃값 비율

# %%
# 교차분석표

def get_crosstab(df, feature):
  crosstab = pd.crosstab(df[feature], df['ProdTaken'], normalize='index') *100
  crosstab = crosstab.reset_index()
  return crosstab

# %%
def plot_pointplot(ax, feature, crosstab):
  ax2 = ax.twinx()
  ax2 = sns.pointplot(x=feature, y=1, data=crosstab, order=crosstab[feature].values,
                      color='black', legend=False)
  ax2.set_ylim(crosstab[1].min()-5, crosstab[1].max()*1.1)
  ax2.set_ylabel('Target 1 Ratio(%)')

# %%
def plot_cat_dist_with_true_ratio(df, features, num_rows, num_cols, size=(15,20)):

  plt.figure(figsize=size)
  grid = gridspec.GridSpec(num_rows, num_cols)
  plt.subplots_adjust(wspace=0.45, hspace=0.3)

  for idx, feature in enumerate(features):
    ax = plt.subplot(grid[idx])
    crosstab = get_crosstab(df, feature)

    sns.countplot(x=feature, data=df, order=crosstab[feature].values, ax=ax)

    write_percent(ax, len(df))

    plot_pointplot(ax, feature, crosstab)

    ax.set_title(f'{feature} Distribution')

# %%
# DurationOfPitch
plot_cat_dist_with_true_ratio(train, ['DurationOfPitch'], num_rows=3, num_cols=2, size=(30,12))

# %% [markdown]
# - 영업사원의 프레젠테이션 기간은 대부분 17일 안에 끝나게 됩니다.
# - 여행 패키지 신청 비율을 보면 18일부터 큰 변동이 있습니다. 이는 데이터의 수가 상대적으로 적어서 영향을 끼친 것일 수도 있고 영업사원의 프레젠테이션 기간이 여행 패키지 신청에 큰 영향을 미치지 않는다고도 생각할 수 있습니다.
# - 6일에서 17일 사이의 여행 패키지 신청 비율을 보면 완만하며 큰 변동폭이 없습니다.
# - 프레젠테이션 만족도에 따른 평균 프레젠테이션 기간을 알아보겠습니다.

# %%
# 만족도별 평균 프레젠테이션 기간
mean_pitch = train.groupby("PitchSatisfactionScore", as_index=False)['DurationOfPitch'].mean()

# 라인 그래프로 표현
x=list(mean_pitch['PitchSatisfactionScore'])
y=list(mean_pitch['DurationOfPitch'])
plt.plot(x, y, color = 'g', linestyle = 'solid', marker = 'o', label = "DurationOfPitch")
plt.xlabel('Pitch Satisfaction Score')
plt.ylabel('Average Duration Of Pitch')
plt.legend()
plt.show()

# %% [markdown]
# - 만족도가 5점인 경우 평균 프레젠테이션 기간이 15일 입니다. 프레젠테이션 만족도 평가를 높이 받고 싶다면 평균 프레젠테이션 기간을 14일 이상으로 잡는 것이 좋겠습니다.
# - 하지만 만족도가 1점인 경우에도 평균 프레젠테이션 기간이 15일에 가깝습니다. 그러므로 기간 뿐만이 아니라 다른 서비스에도 더욱 신경을 써야할 것입니다.
# - 영업사원의 프레젠테이션 기간은 14일에서 17일 사이로 진행하고 추가적으로 다른 서비스의 품질을 높은 것이 중요할 것으로 보입니다.

# %% [markdown]
# ### 2-2. NumberOfFollowups(영업 사원의 프레젠테이션 후 이루어진 후속 조치 수)

# %%
# NumberOfFollowups
plot_cat_dist_with_true_ratio(train, ['NumberOfFollowups'], num_rows=3, num_cols=2, size=(15,12))

# %% [markdown]
# - 영업사원의 후속 조치는 3회에서 4회 정도 이루어집니다.
# - 영업사원의 후속 조치가 많을수록 해당 여행 패키지를 신청하는 사람의 비율이 높아지고 있습니다.
# - 영업사원의 지속적인 관리가 여행 패키지 신청으로 이어지므로 후속 조치 횟수를 늘리는 것을 고려해볼 필요가 있습니다.

# %% [markdown]
# ### 2-3. ProductPitched(영업 사원이 제시한 상품)

# %%
# ProductPitched
plot_cat_dist_with_true_ratio(train, ['ProductPitched'], num_rows=3, num_cols=2, size=(15,12))

# %% [markdown]
# - 영업사원이 제시한 상품 중 가장 많이 제시한 상품은 Basic입니다. 또한 여행 패키지 신청으로 이어진 비율도 가장 높습니다.
# - 가성비가 중요한 고객에게는 Standard 등급보다는 Basic 등급의 상품을 제시하는 것이 좋습니다.
# - 그리고 고급 상품을 찾는 고객에게는 Deluxe 등급의 상품을 제시하는 것이 좋습니다.
# - 추가적으로 영업사원이 제시한 상품별 평균 프레젠테이션 만족도를 알아보겠습니다.

# %%
# 만족도별 평균 프레젠테이션 기간
mean_satis = train.groupby("ProductPitched", as_index=False)['PitchSatisfactionScore'].mean()

# 라인 그래프로 표현
x=list(mean_satis['ProductPitched'])
y=list(mean_satis['PitchSatisfactionScore'])
plt.plot(x, y, color = 'g', linestyle = 'solid', marker = 'o', label = "PitchSatisfactionScore")
plt.xlabel('Product Pitched')
plt.ylabel('Average Pitch Satisfaction Score')
plt.legend()
plt.show()

# %% [markdown]
# - King 등급과 Super Deluxe 등급의 신청 전환율은 낮았지만 평균 프레젠테이션 만족도는 다른 등급에 비해 높습니다.
# - 따라서 King 등급과 Super Deluxe 등급은 연령대, 동반 어린이 유무, 월 수입 등을 고려하여 제시한다면 여행 패키지 신청 전환율이 상승할 것이라 생각합니다.
